# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.2)

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5612900506997363396, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 6278297902496469909
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 11496627010883362161
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11150726272
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 7807457704008205003
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/drive/My Drive/Colab_NoteBooks/ANN/Churn_Modelling.csv")
df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
X=df.iloc[:,3:13]
y=df.iloc[:,13]

# %%
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

# %%
X=pd.concat([X,geography,gender],axis=1)
X=X.drop(['Geography','Gender'],axis=1)
X.head(10)
# Out:
#    CreditScore  Age  Tenure    Balance  ...  EstimatedSalary  Germany  Spain  Male
# 0          619   42       2       0.00  ...        101348.88        0      0     0
# 1          608   41       1   83807.86  ...        112542.58        0      1     0
# 2          502   42       8  159660.80  ...        113931.57        0      0     0
# 3          699   39       1       0.00  ...         93826.63        0      0     0
# 4          850   43       2  125510.82  ...         79084.10        0      1     0
# 5          645   44       8  113755.78  ...        149756.71        0      1     1
# 6          822   50       7       0.00  ...         10062.80        0      0     1
# 7          376   29       4  115046.74  ...        119346.88        1      0     0
# 8          501   44       4  142051.07  ...         74940.50        0      0     1
# 9          684   27       2  134603.88  ...         71725.73        0      0     1
#
# [10 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %%
import keras
from keras.models import Sequential #for any kind od model either it be ANN or CNN or RNN
from Keras.layers import Dense #for any hidden layers that we will create
from keras.layers import Dropout #for using dropout function
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-02dedc5a2fc4> in <module>()
#       1 import keras
#       2 from keras.models import Sequential #for any kind od model either it be ANN or CNN or RNN
# ----> 3 from Keras.layers import Dense #for any hidden layers that we will create
#       4 from keras.layers import Dropout #for using dropout function
#
# ModuleNotFoundError: No module named 'Keras'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import sys
# !{sys. executable} -m pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.12.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.5)

# %%
import keras

# %%
from keras.models import Sequential

# %%
from keras.layers import Dense
from keras.layers import Dropout

# %%
classifier=Sequential()

# %%
#Adding the Input Layer and the first hidden layer
classifier.add(Dense(units=6,kernel_initializer='he_uniform',activation='relu',input_dim=11))

# %%
#Adding the 2nd hidden layer of 6 neuron
classifier.add(Dense(units=6,kernel_initializer='he_uniform',activation='relu'))

# %%
#adding the output layer
classifier.add(Dense(units=1,kernel_initializer='glorot_uniform',activation='sigmoid'))

# %%
#Compiling the Ann model
classifier.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 6)                 72
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 163
# Trainable params: 163
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=classifier.fit(X_train,y_train,validation_split=0.33,batch_size=10,nb_epoch=100)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   
# 5359/5359 [==============================] - 3s 488us/step - loss: 0.3231 - accuracy: 0.8673 - val_loss: 0.3568 - val_accuracy: 0.8607
# Epoch 83/100
# 5359/5359 [==============================] - 3s 512us/step - loss: 0.3226 - accuracy: 0.8662 - val_loss: 0.3546 - val_accuracy: 0.8599
# Epoch 84/100
# 5359/5359 [==============================] - 3s 511us/step - loss: 0.3229 - accuracy: 0.8662 - val_loss: 0.3552 - val_accuracy: 0.8607
# Epoch 85/100
# 5359/5359 [==============================] - 3s 481us/step - loss: 0.3223 - accuracy: 0.8671 - val_loss: 0.3560 - val_accuracy: 0.8614
# Epoch 86/100
# 5359/5359 [==============================] - 3s 497us/step - loss: 0.3223 - accuracy: 0.8666 - val_loss: 0.3559 - val_accuracy: 0.8584
# Epoch 87/100
# 5359/5359 [==============================] - 3s 534us/step - loss: 0.3226 - accuracy: 0.8675 - val_loss: 0.3557 - val_accuracy: 0.8584
# Epoch 88/100
# 5359/5359 [==============================] - 3s 492us/step - loss: 0.3229 - accuracy: 0.8673 - val_loss: 0.3556 - val_accuracy: 0.8591
# Epoch 89/100
# 5359/5359 [==============================] - 3s 509us/step - loss: 0.3224 - accuracy: 0.8681 - val_loss: 0.3571 - val_accuracy: 0.8607
# Epoch 90/100
# 5359/5359 [==============================] - 3s 537us/step - loss: 0.3223 - accuracy: 0.8675 - val_loss: 0.3563 - val_accuracy: 0.8584
# Epoch 91/100
# 5359/5359 [==============================] - 3s 525us/step - loss: 0.3223 - accuracy: 0.8670 - val_loss: 0.3574 - val_accuracy: 0.8607
# Epoch 92/100
# 5359/5359 [==============================] - 3s 514us/step - loss: 0.3222 - accuracy: 0.8656 - val_loss: 0.3551 - val_accuracy: 0.8614
# Epoch 93/100
# 5359/5359 [==============================] - 3s 500us/step - loss: 0.3218 - accuracy: 0.8673 - val_loss: 0.3611 - val_accuracy: 0.8580
# Epoch 94/100
# 5359/5359 [==============================] - 3s 482us/step - loss: 0.3224 - accuracy: 0.8662 - val_loss: 0.3559 - val_accuracy: 0.8561
# Epoch 95/100
# 5359/5359 [==============================] - 3s 496us/step - loss: 0.3215 - accuracy: 0.8673 - val_loss: 0.3572 - val_accuracy: 0.8610
# Epoch 96/100
# 5359/5359 [==============================] - 3s 487us/step - loss: 0.3215 - accuracy: 0.8651 - val_loss: 0.3574 - val_accuracy: 0.8580
# Epoch 97/100
# 5359/5359 [==============================] - 3s 533us/step - loss: 0.3211 - accuracy: 0.8662 - val_loss: 0.3597 - val_accuracy: 0.8599
# Epoch 98/100
# 5359/5359 [==============================] - 3s 497us/step - loss: 0.3219 - accuracy: 0.8670 - val_loss: 0.3567 - val_accuracy: 0.8603
# Epoch 99/100
# 5359/5359 [==============================] - 3s 508us/step - loss: 0.3217 - accuracy: 0.8673 - val_loss: 0.3565 - val_accuracy: 0.8599
# Epoch 100/100
# 5359/5359 [==============================] - 3s 519us/step - loss: 0.3208 - accuracy: 0.8670 - val_loss: 0.3618 - val_accuracy: 0.8561

# %%
y_pred=classifier.predict(X_test)
y_pred=(y_pred>0.5)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_pred,y_test)

# %%
cm
# Out:
# array([[1498,  200],
#        [  97,  205]])

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)

# %%
score
# Out:
# 0.8515
